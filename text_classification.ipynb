# %%
import pandas as pd

books = pd.read_csv('books_cleaned.csv')

# %%
books['categories'].value_counts().reset_index()
# Out:
#                     categories  count
# 0                      Fiction   2111
# 1             Juvenile Fiction    390
# 2    Biography & Autobiography    311
# 3                      History    207
# 4           Literary Criticism    124
# ..                         ...    ...
# 474               Conspiracies      1
# 475       Brothers and sisters      1
# 476             Rock musicians      1
# 477             Community life      1
# 478    Indic fiction (English)      1
#
# [479 rows x 2 columns]

# %%
books["categories"].value_counts().reset_index().query("count > 50")
# Out:
#                    categories  count
# 0                     Fiction   2111
# 1            Juvenile Fiction    390
# 2   Biography & Autobiography    311
# 3                     History    207
# 4          Literary Criticism    124
# 5                  Philosophy    117
# 6                    Religion    117
# 7     Comics & Graphic Novels    116
# 8                       Drama     86
# 9         Juvenile Nonfiction     57
# 10                    Science     56
# 11                     Poetry     51

# %%
books[books["categories"] == "Juvenile Fiction"]
# Out:
#              isbn13      isbn10  \
# 30    9780006646006  000664600X
# 79    9780020442608  0020442602
# 85    9780030547744  0030547741
# 86    9780060000141  0060000147
# 87    9780060001537  0060001534
# ...             ...         ...
# 4845  9781590385814  1590385810
# 4930  9781596792500  1596792507
# 4942  9781599900056  159990005X
# 5010  9781844580514  1844580512
# 5157  9781932416374  1932416374
#
#                                                   title  \
# 30                                   Ocean Star Express
# 79                       The voyage of the Dawn Treader
# 85                             Where the Red Fern Grows
# 86                                       Poppy's Return
# 87                                    Diary of a Spider
# ...                                                 ...
# 4845                                         Fablehaven
# 4930  Sherlock Holmes and the Case of the Hound of t...
# 4942                                    The Drift House
# 5010                               Attack of the Jaguar
# 5157                The Very Persistent Gappers of Frip
#
#                                   authors        categories  \
# 30               Mark Haddon;Peter Sutton  Juvenile Fiction
# 79                    Clive Staples Lewis  Juvenile Fiction
# 85                           Wilson Rawls  Juvenile Fiction
# 86                                    Avi  Juvenile Fiction
# 87                          Doreen Cronin  Juvenile Fiction
# ...                                   ...               ...
# 4845                         Brandon Mull  Juvenile Fiction
# 4930  Arthur Conan Doyle;Malvina G. Vogel  Juvenile Fiction
# 4942                            Dale Peck  Juvenile Fiction
# 5010                         M. A. Harvey  Juvenile Fiction
# 5157           George Saunders;Lane Smith  Juvenile Fiction
#
#                                               thumbnail  \
# 30    http://books.google.com/books/content?id=I2QZA...
# 79    http://books.google.com/books/content?id=fDD3C...
# 85    http://books.google.com/books/content?id=IHpRw...
# 86    http://books.google.com/books/content?id=XbcMJ...
# 87    http://books.google.com/books/content?id=UWvZo...
# ...                                                 ...
# 4845  http://books.google.com/books/content?id=tbVIP...
# 4930  http://books.google.com/books/content?id=EWgWP...
# 4942  http://books.google.com/books/content?id=kbwPY...
# 5010  http://books.google.com/books/content?id=3HUdt...
# 5157  http://books.google.com/books/content?id=xYJOP...
#
#                                             description  published_year  \
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 79    The "Dawn Treader" is the first ship Narnia ha...          1970.0
# 85    A young boy living in the Ozarks achieves his ...          2000.0
# 86    There's trouble at Gray House, the girlhood ho...          2006.0
# 87    This is the diary ... of a spider. But don't b...          2005.0
# ...                                                 ...             ...
# 4845  When Kendra and Seth go to stay at their grand...          2006.0
# 4930  Sherlock Holmes and Dr. Watson travel to the b...          2005.0
# 4942  Sent to stay with their uncle in a ship-like h...          2006.0
# 5010  This training manual for operatives of Xtreme ...          2004.0
# 5157  A novel set in the seaside village of Frip fol...          2006.0
#
#       average_rating  num_pages  ratings_count  \
# 30              3.50       32.0            1.0
# 79              4.09      216.0         2869.0
# 85              4.37      288.0           95.0
# 86              3.99      256.0         1086.0
# 87              4.25       40.0         7903.0
# ...              ...        ...            ...
# 4845            4.09      351.0       111896.0
# 4930            4.51      237.0           28.0
# 4942            3.64      437.0          595.0
# 5010            3.40      125.0            4.0
# 5157            4.11       84.0         2317.0
#
#                                      title_and_subtitle  \
# 30                                   Ocean Star Express
# 79                       The voyage of the Dawn Treader
# 85    Where the Red Fern Grows:The Story of Two Dogs...
# 86                                       Poppy's Return
# 87                                    Diary of a Spider
# ...                                                 ...
# 4845                                         Fablehaven
# 4930  Sherlock Holmes and the Case of the Hound of t...
# 4942                   The Drift House:The First Voyage
# 5010                               Attack of the Jaguar
# 5157                The Very Persistent Gappers of Frip
#
#                                      tagged_description
# 30    9780006646006 Joe and his parents are enjoying...
# 79    9780020442608 The "Dawn Treader" is the first ...
# 85    9780030547744 A young boy living in the Ozarks...
# 86    9780060000141 There's trouble at Gray House, t...
# 87    9780060001537 This is the diary ... of a spide...
# ...                                                 ...
# 4845  9781590385814 When Kendra and Seth go to stay ...
# 4930  9781596792500 Sherlock Holmes and Dr. Watson t...
# 4942  9781599900056 Sent to stay with their uncle in...
# 5010  9781844580514 This training manual for operati...
# 5157  9781932416374 A novel set in the seaside villa...
#
# [390 rows x 13 columns]

# %%
books[books["categories"] == "Juvenile Nonfiction"]
# Out:
#              isbn13      isbn10  \
# 107   9780060277406  0060277408
# 108   9780060278427  0060278420
# 228   9780060782139  0060782137
# 267   9780060882600  0060882603
# 434   9780064462044  0064462048
# 435   9780064462341  006446234X
# 439   9780066236179  0066236177
# 812   9780142302279  0142302279
# 821   9780142407226  0142407224
# 823   9780142407929  0142407925
# 1014  9780198320272  0198320272
# 1074  9780237525378  0237525372
# 1739  9780375812934  0375812938
# 1742  9780375823787  0375823786
# 1770  9780380732548  0380732548
# 1972  9780395776087  0395776082
# 2105  9780439314558  0439314550
# 2117  9780439420068  0439420067
# 2139  9780439736466  0439736463
# 2183  9780440229353  0440229359
# 2211  9780440419174  0440419174
# 2320  9780448437439  0448437430
# 2323  9780448444826  0448444828
# 2503  9780486276809  0486276805
# 2509  9780486296388  0486296385
# 2609  9780521618748  0521618746
# 2615  9780525469780  0525469788
# 2858  9780590032490  0590032496
# 2859  9780590103879  0590103873
# 2897  9780618111206  0618111204
# 3133  9780679890522  0679890521
# 3202  9780689833762  0689833768
# 3203  9780689834196  0689834195
# 3204  9780689835612  0689835612
# 2859  9780590103879 A Down-to-Earth Approach James H...
# 2897  9780618111206 With powerful and rare photos by...
# 3133  9780679890522 In 1838, settlers moving west fo...
# 3202  9780689833762 Knock, knock. Who's there? Someo...
# 3203  9780689834196 Young Michael Jordan, who is sma...
# 3204  9780689835612 Is Mommy behind the chair? Is Mo...
# 3219  9780689869907 In this story based on a case fr...
# 3223  9780689876707 PopTV is going to follow Star ar...
# 3263  9780723247791 This original, authorised versio...
# 3270  9780736805995 Excerpts from the girlhood diary...
# 3292  9780739844328 Presents the life of Bill Gates,...
# 3522  9780753459645 What is a leap year? Why are bee...
# 3552  9780756614195 Glorious full-color illustration...
# 3565  9780761417101 Looks at the events leading up t...
# 3797  9780789458209 Photographs and text explore the...
# 3798  9780791070482 Presents a collection of critica...
# 3799  9780791081266 One of Edith Wharton's most crit...
# 3800  9780792241737 Offers the true account of two y...
# 3861  9780805069853 An introduction to Robert Frost ...
# 3863  9780805071061 Provides the story of the black ...
# 3921  9780810935204 Lewis Carroll's classic and inve...
# 4069  9780822560562 Chronicles the life and career o...
# 4072  9780823410781 Traces the life of the young Jew...
# 4409  9781400307845 Using selections from her works ...
# 4596  9781560067849 Discusses the young adult book "...
# 4744  9781580495868 As he faces battle in the Civil ...
# 4808  9781586853334 There's this boy. Let's say he's...
# 5041  9781857232097 The fifth book in Robert Jordan'...
# 5142  9781931414166 Describes the construction of th...

# %%
category_mapping = {'Fiction' : "Fiction",
                    'Juvenile Fiction': "Children's Fiction",
                    'Biography & Autobiography': "Nonfiction",
                    'History': "Nonfiction",
                    'Literary Criticism': "Nonfiction",
                    'Philosophy': "Nonfiction",
                    'Religion': "Nonfiction",
                    "Comics & Graphic Novels": "Fiction",
                    'Drama':"Fiction",
                    'Juvenile Nonfiction': "Children's Nonfiction",
                    'Science': "Nonfiction",
                    'Poetry': "Fiction",
                    }

books["simple_categories"] = books["categories"].map(category_mapping)

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                  Spider's Web:A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195      I Am that:Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...               NaN
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...               NaN
# 4     9780006280934 "In The Problem of Pain, C.S. Le...               NaN
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...               NaN
# 5193  9788173031014 This book tells the tale of a ma...               NaN
# 5194  9788179921623 Wisdom to Create a Life of Passi...               NaN
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
# [5197 rows x 14 columns]

# %%
books[~(books["simple_categories"].isna())]
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 2     9780006178736  0006178731             Rage of angels
# 8     9780006482079  0006482074        Warhost of Vastmark
# 30    9780006646006  000664600X         Ocean Star Express
# 46    9780007121014  0007121016         Taken at the Flood
# ...             ...         ...                        ...
# 5178  9781933648279  1933648279  Night Has a Thousand Eyes
# 5188  9784770028969  4770028962         Coin Locker Babies
# 5189  9788122200850  8122200850           Cry, the Peacock
# 5195  9788185300535  8185300534                  I Am that
# 5196  9789027712059  9027712050   The Berlin Phenomenology
#
#                                            authors        categories  \
# 0                               Marilynne Robinson           Fiction
# 2                                   Sidney Sheldon           Fiction
# 8                                      Janny Wurts           Fiction
# 30                        Mark Haddon;Peter Sutton  Juvenile Fiction
# 46                                 Agatha Christie           Fiction
# ...                                            ...               ...
# 5178                              Cornell Woolrich           Fiction
# 5188                                           村上龍           Fiction
# 5189                                   Anita Desai           Fiction
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit        Philosophy
# 5196                 Georg Wilhelm Friedrich Hegel           History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 8     http://books.google.com/books/content?id=uOL0f...
# 30    http://books.google.com/books/content?id=I2QZA...
# 46    http://books.google.com/books/content?id=3gWlx...
# ...                                                 ...
# 5178  http://books.google.com/books/content?id=3Gk6s...
# 5188  http://books.google.com/books/content?id=87DJw...
# 5189  http://books.google.com/books/content?id=_QKwV...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 8     Tricked once more by his wily half-brother, Ly...          1995.0
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 46    A Few Weeks After Marrying An Attractive Young...          2002.0
# ...                                                 ...             ...
# 5178  "Cornell Woolrich's novels define the essence ...          2007.0
# 5188  Rescued from the lockers in which they were le...          2002.0
# 5189  This book is the story of a young girl obsesse...          1980.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 2               3.93      512.0        29532.0
# 8               4.03      522.0         2966.0
# 30              3.50       32.0            1.0
# 46              3.71      352.0         8852.0
# ...              ...        ...            ...
# 5178            3.77      344.0          680.0
# 5188            3.75      393.0         5560.0
# 5189            3.22      218.0          134.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                  title_and_subtitle  \
# 0                                            Gilead
# 2                                    Rage of angels
# 8                               Warhost of Vastmark
# 30                               Ocean Star Express
# 46                               Taken at the Flood
# ...                                             ...
# 5178                      Night Has a Thousand Eyes
# 5188                             Coin Locker Babies
# 5189                               Cry, the Peacock
# 5195  I Am that:Talks with Sri Nisargadatta Maharaj
# 5196                       The Berlin Phenomenology
#
#                                      tagged_description   simple_categories
# 0     9780002005883 A NOVEL THAT READERS and critics...             Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...             Fiction
# 8     9780006482079 Tricked once more by his wily ha...             Fiction
# 30    9780006646006 Joe and his parents are enjoying...  Children's Fiction
# 46    9780007121014 A Few Weeks After Marrying An At...             Fiction
# ...                                                 ...                 ...
# 5178  9781933648279 "Cornell Woolrich's novels defin...             Fiction
# 5188  9784770028969 Rescued from the lockers in whic...             Fiction
# 5189  9788122200850 This book is the story of a youn...             Fiction
# 5195  9788185300535 This collection of the timeless ...          Nonfiction
# 5196  9789027712059 Since the three volume edition o...          Nonfiction
#
# [3743 rows x 14 columns]

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
# %pip install tf-keras
fiction_categories = ["Fiction", "Nonfiction"]
pipe = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# Collecting tf-keras
#   Downloading tf_keras-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow<2.19,>=2.18 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tf-keras) (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.43.0)
# Requirement already satisfied: rich in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\zainabfr\anaconda3-copy\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow<2.19,>=2.18->tf-keras) (0.1.0)
# Downloading tf_keras-2.18.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 330.3 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/1.7 MB 435.7 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.2/1.7 MB 952.6 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.7 MB 962.7 kB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.7 MB 1.1 MB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.7 MB 1.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.4/1.7 MB 1.3 MB/s eta 0:00:02
#    ------------ --------------------------- 0.6/1.7 MB 1.3 MB/s eta 0:00:01
#    ------------- -------------------------- 0.6/1.7 MB 1.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 1.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.7 MB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.7 MB 1.4 MB/s eta 0:00:01
#    --------------------- ------------------ 0.9/1.7 MB 1.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.7 MB 1.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.7 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.2/1.7 MB 1.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.7 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.7 MB/s eta 0:00:00
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.18.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING:tensorflow:From c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# WARNING:tensorflow:From c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBartForSequenceClassification: ['model.encoder.version', 'model.decoder.version']
# - This IS expected if you are initializing TFBartForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBartForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBartForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForSequenceClassification for predictions without further training.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use 0

# %%
sequence  = books.loc[books["simple_categories"]== "Fiction", "description"].reset_index(drop=True)[0]

# %%
pipe(sequence, fiction_categories)
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#  'labels': ['Fiction', 'Nonfiction'],
#  'scores': [0.8438268303871155, 0.1561731994152069]}

# %%
import numpy as np
max_index = np.argmax(pipe(sequence, fiction_categories)["scores"])
max_label = pipe(sequence, fiction_categories)["labels"][max_index]
max_label
# Out:
# 'Fiction'

# %%
def generate_predictions(sequence, categories):
    predictions = pipe(sequence, categories)
    max_index = np.argmax(predictions["scores"])
    max_label = predictions["labels"][max_index]
    return max_label

# %%
from tqdm import tqdm

actual_cats = []
predicted_cats = []

for i in tqdm(range(0,300)):
    sequence = books.loc[books["simple_categories"]== "Fiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Fiction"]
# Out:
#  15%|█▍        | 44/300 [05:35<32:33,  7.63s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32832\1713729483.py in ?()
#       4 predicted_cats = []
#       5
#       6 for i in tqdm(range(0,300)):
#       7     sequence = books.loc[books["simple_categories"]== "Fiction", "description"].reset_index(drop=True)[i]
# ----> 8     predicted_cats += [generate_predictions(sequence, fiction_categories)]
#       9     actual_cats += ["Fiction"]
#
# ~\AppData\Local\Temp\ipykernel_32832\4218000938.py in ?(sequence, categories)
#       1 def generate_predictions(sequence, categories):
# ----> 2     predictions = pipe(sequence, categories)
#       3     max_index = np.argmax(predictions["scores"])
#       4     max_label = predictions["labels"][max_index]
#       5     return max_label
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\zero_shot_classification.py in ?(self, sequences, *args, **kwargs)
#     202             kwargs["candidate_labels"] = args[0]
#     203         else:
#     204             raise ValueError(f"Unable to understand extra arguments {args}")
#     205
# --> 206         return super().__call__(sequences, **kwargs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\base.py in ?(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1364                     )
#    1365                 )
#    1366             )
#    1367         else:
# -> 1368             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\base.py in ?(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1394     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1395         all_outputs = []
#    1396         for model_inputs in self.preprocess(inputs, **preprocess_params):
# -> 1397             model_outputs = self.forward(model_inputs, **forward_params)
#    1398             all_outputs.append(model_outputs)
#    1399         outputs = self.postprocess(all_outputs, **postprocess_params)
#    1400         return outputs
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\base.py in ?(self, model_inputs, **forward_params)
#    1266     def forward(self, model_inputs, **forward_params):
#    1267         with self.device_placement():
#    1268             if self.framework == "tf":
#    1269                 model_inputs["training"] = False
# -> 1270                 model_outputs = self._forward(model_inputs, **forward_params)
#    1271             elif self.framework == "pt":
#    1272                 inference_context = self.get_inference_context()
#    1273                 with inference_context():
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\zero_shot_classification.py in ?(self, inputs)
#     225         # `XXXForSequenceClassification` models should not use `use_cache=True` even if it's supported
#     226         model_forward = self.model.forward if self.framework == "pt" else self.model.call
#     227         if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     228             model_inputs["use_cache"] = False
# --> 229         outputs = self.model(**model_inputs)
#     230
#     231         model_outputs = {
#     232             "candidate_label": candidate_label,
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\training.py in ?(self, *args, **kwargs)
#     584                 super().__call__(inputs, *copied_args, **copied_kwargs)
#     585
#     586             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     587
# --> 588         return super().__call__(*args, **kwargs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1138
#    1139                 with autocast_variable.enable_auto_cast_variables(
#    1140                     self._compute_dtype_object
#    1141                 ):
# -> 1142                     outputs = call_fn(inputs, *args, **kwargs)
#    1143
#    1144                 if self._activity_regularizer:
#    1145                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\modeling_tf_utils.py in ?(self, *args, **kwargs)
#     433         else:
#     434             config = self.config
#     435
#     436         unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437         return func(self, **unpacked_inputs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py in ?(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, decoder_position_ids, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, labels, training)
#    1626             raise NotImplementedError(
#    1627                 f"Passing input embeddings is currently not supported for {self.__class__.__name__}"
#    1628             )
#    1629
# -> 1630         outputs = self.model(
#    1631             input_ids=input_ids,
#    1632             attention_mask=attention_mask,
#    1633             decoder_input_ids=decoder_input_ids,
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1138
#    1139                 with autocast_variable.enable_auto_cast_variables(
#    1140                     self._compute_dtype_object
#    1141                 ):
# -> 1142                     outputs = call_fn(inputs, *args, **kwargs)
#    1143
#    1144                 if self._activity_regularizer:
#    1145                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\modeling_tf_utils.py in ?(self, *args, **kwargs)
#     433         else:
#     434             config = self.config
#     435
#     436         unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437         return func(self, **unpacked_inputs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py in ?(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, decoder_position_ids, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, training, **kwargs)
#    1213         # If the user passed a TFBaseModelOutput for encoder_outputs, we wrap it in a tuple when return_dict=False
#    1214         elif not return_dict and not isinstance(encoder_outputs, tuple):
#    1215             encoder_outputs = encoder_outputs.to_tuple()
#    1216
# -> 1217         decoder_outputs = self.decoder(
#    1218             decoder_input_ids,
#    1219             attention_mask=decoder_attention_mask,
#    1220             position_ids=decoder_position_ids,
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1138
#    1139                 with autocast_variable.enable_auto_cast_variables(
#    1140                     self._compute_dtype_object
#    1141                 ):
# -> 1142                     outputs = call_fn(inputs, *args, **kwargs)
#    1143
#    1144                 if self._activity_regularizer:
#    1145                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\modeling_tf_utils.py in ?(self, *args, **kwargs)
#     433         else:
#     434             config = self.config
#     435
#     436         unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437         return func(self, **unpacked_inputs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py in ?(self, input_ids, inputs_embeds, attention_mask, position_ids, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, training)
#    1079                 continue
#    1080
#    1081             past_key_value = past_key_values[idx] if past_key_values is not None else None
#    1082
# -> 1083             hidden_states, layer_self_attn, layer_cross_attn, present_key_value = decoder_layer(
#    1084                 hidden_states,
#    1085                 attention_mask=combined_attention_mask,
#    1086                 encoder_hidden_states=encoder_hidden_states,
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1138
#    1139                 with autocast_variable.enable_auto_cast_variables(
#    1140                     self._compute_dtype_object
#    1141                 ):
# -> 1142                     outputs = call_fn(inputs, *args, **kwargs)
#    1143
#    1144                 if self._activity_regularizer:
#    1145                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py in ?(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, training)
#     468             residual = hidden_states
#     469
#     470             # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     471             cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 472             hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     473                 hidden_states=hidden_states,
#     474                 key_value_states=encoder_hidden_states,
#     475                 attention_mask=encoder_attention_mask,
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py in ?(self, *args, **kwargs)
#    1138
#    1139                 with autocast_variable.enable_auto_cast_variables(
#    1140                     self._compute_dtype_object
#    1141                 ):
# -> 1142                     outputs = call_fn(inputs, *args, **kwargs)
#    1143
#    1144                 if self._activity_regularizer:
#    1145                     self._handle_activity_regularization(inputs, outputs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py in ?(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, training)
#     255             attention_mask = tf.cast(attention_mask, dtype=attn_weights.dtype)
#     256             attn_weights = tf.reshape(attn_weights, (bsz, self.num_heads, tgt_len, src_len)) + attention_mask
#     257             attn_weights = tf.reshape(attn_weights, (bsz * self.num_heads, tgt_len, src_len))
#     258
# --> 259         attn_weights = stable_softmax(attn_weights, axis=-1)
#     260
#     261         if layer_head_mask is not None:
#     262             tf.debugging.assert_equal(
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\tf_utils.py in ?(logits, axis, name)
#      68             A Tensor. Has the same type and shape as logits.
#      69     """
#      70     # TODO: When the issue linked above gets sorted, add a check on TF version here and use the original function if
#      71     # it has the fix. After we drop the support for unfixed versions, remove this function.
# ---> 72     return tf.nn.softmax(logits=logits + 1e-9, axis=axis, name=name)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(logits, axis, name)
#    3903       dimension of `logits`.
#    3904   """
#    3905   if axis is None:
#    3906     axis = -1
# -> 3907   return _wrap_2d_function(logits, gen_nn_ops.softmax, axis, name)
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(inputs, compute_op, dim, name)
#    3821   shape = inputs.get_shape()
#    3822   is_last_dim = (dim == -1) or (dim == shape.ndims - 1)
#    3823
#    3824   if is_last_dim:
# -> 3825     return compute_op(inputs, name=name)
#    3826
#    3827   dim_val = dim
#    3828   if isinstance(dim, tensor_lib.Tensor):
#
# c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in ?(logits, name)
#   12694         _ctx, "Softmax", name, logits)
#   12695       return _result
#   12696     except _core._NotOkStatusException as e:
#   12697       _ops.raise_from_not_ok_status(e, name)
# > 12698     except _core._FallbackException:
#   12699       pass
#   12700     try:
#   12701       return softmax_eager_fallback(
#
# KeyboardInterrupt:

# %%
for i in tqdm(range(0,300)):
    sequence = books.loc[books["simple_categories"]== "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Nonfiction"]

# %%
predictions_df = pd.DataFrame({"actual": actual_cats, "predicted": predicted_cats})

# %%
predictions_df
# Out:
#      actual   predicted
# 0   Fiction     Fiction
# 1   Fiction     Fiction
# 2   Fiction     Fiction
# 3   Fiction  Nonfiction
# 4   Fiction     Fiction
# 5   Fiction     Fiction
# 6   Fiction     Fiction
# 7   Fiction     Fiction
# 8   Fiction     Fiction
# 9   Fiction     Fiction
# 10  Fiction     Fiction
# 11  Fiction     Fiction
# 12  Fiction     Fiction
# 13  Fiction     Fiction
# 14  Fiction     Fiction
# 15  Fiction     Fiction
# 16  Fiction     Fiction
# 17  Fiction     Fiction
# 18  Fiction     Fiction
# 19  Fiction  Nonfiction
# 20  Fiction     Fiction
# 21  Fiction  Nonfiction
# 22  Fiction  Nonfiction
# 23  Fiction     Fiction
# 24  Fiction     Fiction
# 25  Fiction  Nonfiction
# 26  Fiction     Fiction
# 27  Fiction  Nonfiction
# 28  Fiction  Nonfiction
# 29  Fiction     Fiction
# 30  Fiction     Fiction
# 31  Fiction     Fiction
# 32  Fiction     Fiction
# 33  Fiction     Fiction
# 34  Fiction  Nonfiction
# 35  Fiction  Nonfiction
# 36  Fiction     Fiction
# 37  Fiction     Fiction
# 38  Fiction  Nonfiction
# 39  Fiction     Fiction
# 40  Fiction  Nonfiction
# 41  Fiction  Nonfiction
# 42  Fiction     Fiction
# 43  Fiction     Fiction

# %%
predictions_df["correct_prediction"] = (np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'actual_categories'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 predictions_df["correct_prediction"] = (np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0))
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'actual_categories'

# %%
predictions_df["correct_prediction"].sum()/ len(predictions_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'correct_prediction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 predictions_df["correct_prediction"].sum()/ len(predictions_df)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'correct_prediction'

# %%
isbns = []
predicted_cats = []

missing_cats = books.loc[books["simple_categories"].isna(), ["isbn13", "description"]].reset_index(drop=True)

# %%
for i in tqdm(range(0, len(missing_cats))):
    sequence = missing_cats["description"][i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    isbns += [missing_cats["isbn13"][i]]
# Out:
#   0%|          | 4/1454 [00:20<2:04:55,  5.17s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 for i in tqdm(range(0, len(missing_cats))):
#       2     sequence = missing_cats["description"][i]
# ----> 3     predicted_cats += [generate_predictions(sequence, fiction_categories)]
#       4     isbns += [missing_cats["isbn13"][i]]
#
# Cell In[18], line 2, in generate_predictions(sequence, categories)
#       1 def generate_predictions(sequence, categories):
# ----> 2     predictions = pipe(sequence, categories)
#       3     max_index = np.argmax(predictions["scores"])
#       4     max_label = predictions["labels"][max_index]
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\zero_shot_classification.py:206, in ZeroShotClassificationPipeline.__call__(self, sequences, *args, **kwargs)
#     203 else:
#     204     raise ValueError(f"Unable to understand extra arguments {args}")
# --> 206 return super().__call__(sequences, **kwargs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\base.py:1368, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1360     return next(
#    1361         iter(
#    1362             self.get_iterator(
#    (...)
#    1365         )
#    1366     )
#    1367 else:
# -> 1368     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\base.py:1397, in ChunkPipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1395 all_outputs = []
#    1396 for model_inputs in self.preprocess(inputs, **preprocess_params):
# -> 1397     model_outputs = self.forward(model_inputs, **forward_params)
#    1398     all_outputs.append(model_outputs)
#    1399 outputs = self.postprocess(all_outputs, **postprocess_params)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\base.py:1270, in Pipeline.forward(self, model_inputs, **forward_params)
#    1268 if self.framework == "tf":
#    1269     model_inputs["training"] = False
# -> 1270     model_outputs = self._forward(model_inputs, **forward_params)
#    1271 elif self.framework == "pt":
#    1272     inference_context = self.get_inference_context()
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\pipelines\zero_shot_classification.py:229, in ZeroShotClassificationPipeline._forward(self, inputs)
#     227 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     228     model_inputs["use_cache"] = False
# --> 229 outputs = self.model(**model_inputs)
#     231 model_outputs = {
#     232     "candidate_label": candidate_label,
#     233     "sequence": sequence,
#     234     "is_last": inputs["is_last"],
#     235     **outputs,
#     236 }
#     237 return model_outputs
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\training.py:588, in Model.__call__(self, *args, **kwargs)
#     584         super().__call__(inputs, *copied_args, **copied_kwargs)
#     586     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 588 return super().__call__(*args, **kwargs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py:1142, in Layer.__call__(self, *args, **kwargs)
#    1137     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1139 with autocast_variable.enable_auto_cast_variables(
#    1140     self._compute_dtype_object
#    1141 ):
# -> 1142     outputs = call_fn(inputs, *args, **kwargs)
#    1144 if self._activity_regularizer:
#    1145     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\modeling_tf_utils.py:437, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     434     config = self.config
#     436 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437 return func(self, **unpacked_inputs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py:1630, in TFBartForSequenceClassification.call(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, decoder_position_ids, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, labels, training)
#    1625 if input_ids is None and inputs_embeds is not None:
#    1626     raise NotImplementedError(
#    1627         f"Passing input embeddings is currently not supported for {self.__class__.__name__}"
#    1628     )
# -> 1630 outputs = self.model(
#    1631     input_ids=input_ids,
#    1632     attention_mask=attention_mask,
#    1633     decoder_input_ids=decoder_input_ids,
#    1634     decoder_attention_mask=decoder_attention_mask,
#    1635     decoder_position_ids=decoder_position_ids,
#    1636     head_mask=head_mask,
#    1637     decoder_head_mask=decoder_head_mask,
#    1638     cross_attn_head_mask=cross_attn_head_mask,
#    1639     encoder_outputs=encoder_outputs,
#    1640     past_key_values=past_key_values,
#    1641     inputs_embeds=inputs_embeds,
#    1642     decoder_inputs_embeds=decoder_inputs_embeds,
#    1643     use_cache=use_cache,
#    1644     output_attentions=output_attentions,
#    1645     output_hidden_states=output_hidden_states,
#    1646     return_dict=return_dict,
#    1647     training=training,
#    1648 )
#    1650 last_hidden_state = outputs[0]
#    1651 eos_mask = tf.equal(input_ids, self.config.eos_token_id)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py:1142, in Layer.__call__(self, *args, **kwargs)
#    1137     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1139 with autocast_variable.enable_auto_cast_variables(
#    1140     self._compute_dtype_object
#    1141 ):
# -> 1142     outputs = call_fn(inputs, *args, **kwargs)
#    1144 if self._activity_regularizer:
#    1145     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\modeling_tf_utils.py:437, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     434     config = self.config
#     436 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437 return func(self, **unpacked_inputs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py:1196, in TFBartMainLayer.call(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, decoder_position_ids, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, training, **kwargs)
#    1191     decoder_input_ids = shift_tokens_right(
#    1192         input_ids, self.config.pad_token_id, self.config.decoder_start_token_id
#    1193     )
#    1195 if encoder_outputs is None:
# -> 1196     encoder_outputs = self.encoder(
#    1197         input_ids=input_ids,
#    1198         attention_mask=attention_mask,
#    1199         head_mask=head_mask,
#    1200         inputs_embeds=inputs_embeds,
#    1201         output_attentions=output_attentions,
#    1202         output_hidden_states=output_hidden_states,
#    1203         return_dict=return_dict,
#    1204         training=training,
#    1205     )
#    1206 # If the user passed a tuple for encoder_outputs, we wrap it in a TFBaseModelOutput when return_dict=True
#    1207 elif return_dict and not isinstance(encoder_outputs, TFBaseModelOutput):
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py:1142, in Layer.__call__(self, *args, **kwargs)
#    1137     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1139 with autocast_variable.enable_auto_cast_variables(
#    1140     self._compute_dtype_object
#    1141 ):
# -> 1142     outputs = call_fn(inputs, *args, **kwargs)
#    1144 if self._activity_regularizer:
#    1145     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\modeling_tf_utils.py:437, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     434     config = self.config
#     436 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 437 return func(self, **unpacked_inputs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py:868, in TFBartEncoder.call(self, input_ids, inputs_embeds, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, training)
#     865 if training and (dropout_probability < self.layerdrop):  # skip the layer
#     866     continue
# --> 868 hidden_states, attn = encoder_layer(
#     869     hidden_states,
#     870     attention_mask,
#     871     head_mask[idx] if head_mask is not None else None,
#     872 )
#     874 if output_attentions:
#     875     all_attentions += (attn,)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py:1142, in Layer.__call__(self, *args, **kwargs)
#    1137     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1139 with autocast_variable.enable_auto_cast_variables(
#    1140     self._compute_dtype_object
#    1141 ):
# -> 1142     outputs = call_fn(inputs, *args, **kwargs)
#    1144 if self._activity_regularizer:
#    1145     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py:348, in TFBartEncoderLayer.call(self, hidden_states, attention_mask, layer_head_mask, training)
#     339 """
#     340 Args:
#     341     hidden_states (`tf.Tensor`): input to the layer of shape `(batch, seq_len, embed_dim)`
#    (...)
#     345         `(encoder_attention_heads,)`
#     346 """
#     347 residual = hidden_states
# --> 348 hidden_states, self_attn_weights, _ = self.self_attn(
#     349     hidden_states=hidden_states, attention_mask=attention_mask, layer_head_mask=layer_head_mask
#     350 )
#     352 tf.debugging.assert_equal(
#     353     shape_list(hidden_states),
#     354     shape_list(residual),
#     355     message=f"Self attn modified the shape of query {shape_list(residual)} to {shape_list(hidden_states)}",
#     356 )
#     358 hidden_states = self.dropout(hidden_states, training=training)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\engine\base_layer.py:1142, in Layer.__call__(self, *args, **kwargs)
#    1137     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1139 with autocast_variable.enable_auto_cast_variables(
#    1140     self._compute_dtype_object
#    1141 ):
# -> 1142     outputs = call_fn(inputs, *args, **kwargs)
#    1144 if self._activity_regularizer:
#    1145     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\transformers\models\bart\modeling_tf_bart.py:257, in TFBartAttention.call(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, training)
#     255     attention_mask = tf.cast(attention_mask, dtype=attn_weights.dtype)
#     256     attn_weights = tf.reshape(attn_weights, (bsz, self.num_heads, tgt_len, src_len)) + attention_mask
# --> 257     attn_weights = tf.reshape(attn_weights, (bsz * self.num_heads, tgt_len, src_len))
#     259 attn_weights = stable_softmax(attn_weights, axis=-1)
#     261 if layer_head_mask is not None:
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\ops\array_ops.py:199, in reshape(tensor, shape, name)
#      63 @tf_export("reshape", v1=["reshape", "manip.reshape"])
#      64 @dispatch.add_dispatch_support
#      65 def reshape(tensor, shape, name=None):  # pylint: disable=redefined-outer-name
#      66   r"""Reshapes a tensor.
#      67
#      68   Given `tensor`, this operation returns a new `tf.Tensor` that has the same
#    (...)
#     197     A `Tensor`. Has the same type as `tensor`.
#     198   """
# --> 199   result = gen_array_ops.reshape(tensor, shape, name)
#     200   shape_util.maybe_set_static_shape(result, shape)
#     201   return result
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py:10889, in reshape(tensor, shape, name)
#   10887   pass
#   10888 try:
# > 10889   return reshape_eager_fallback(
#   10890       tensor, shape, name=name, ctx=_ctx)
#   10891 except _core._SymbolicException:
#   10892   pass  # Add nodes to the TensorFlow graph.
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\ops\gen_array_ops.py:10914, in reshape_eager_fallback(tensor, shape, name, ctx)
#   10912 _inputs_flat = [tensor, shape]
#   10913 _attrs = ("T", _attr_T, "Tshape", _attr_Tshape)
# > 10914 _result = _execute.execute(b"Reshape", 1, inputs=_inputs_flat, attrs=_attrs,
#   10915                            ctx=ctx, name=name)
#   10916 if _execute.must_record_gradient():
#   10917   _execute.record_gradient(
#   10918       "Reshape", _inputs_flat, _attrs, _result)
#
# File c:\Users\ZainabFR\anaconda3-copy\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
books = pd.merge(books, missing_cats, on="isbn13", how="left")
books["simple_categories"] = np.where(books["simple_categories"].isna(), predicted_cats, books["simple_categories"])
books = books.drop(columns=["predicted_cats"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 books = pd.merge(books, missing_cats, on="isbn13", how="left")
# ----> 2 books["simple_categories"] = np.where(books["simple_categories"].isna(), predicted_cats, books["simple_categories"])
#       3 books = books.drop(columns=["predicted_cats"])
#
# ValueError: operands could not be broadcast together with shapes (5197,) (4,) (5197,)

# %%
books[books["categories"].str.lower().isin(["romance","science fiction", "scifi","fantasy","horror","mystery","thriller","comedy","crime","historical"])]
# Out:
#              isbn13      isbn10                                     title  \
# 24    9780006513087  0006513085                                   Gravity
# 475   9780099410355  0099410354                                   Traitor
# 5057  In the year 2100, mankind on Earth, settlers i...          2000.0
#
#       average_rating  num_pages  ratings_count  \
# 24              4.04      342.0         8024.0
# 475             4.00      320.0         6765.0
# 478             3.39      298.0           34.0
# 491             3.86      774.0        26145.0
# 1090            3.91      384.0          253.0
# 1435            3.92      672.0          563.0
# 1439            3.23      183.0           10.0
# 2845            4.16      272.0          412.0
# 2860            4.21      189.0          860.0
# 3288            4.44      376.0          439.0
# 3289            4.35      646.0          165.0
# 3563            3.88      394.0       135778.0
# 4483            4.26     1260.0           84.0
# 4979            3.79      638.0          317.0
# 5040            4.19      411.0        30779.0
# 5057            4.09      288.0        41304.0
#
#                                    title_and_subtitle  \
# 24                                            Gravity
# 475                                           Traitor
# 478   Yeats is Dead!:A Novel by Fifteen Irish Writers
# 491                                    Blackwood Farm
# 1090                                 The Silmarillion
# 1435                       Stranger in a Strange Land
# 1439                             Visions from Nowhere
# 2845                                           Replay
# 2860             The lion, the witch and the wardrobe
# 3288                                  Wizard's Castle
# 3289                                     Time Quartet
# 3563                     20,000 Leagues Under the Sea
# 4483         The Voyage of the Jerle Shannara Trilogy
# 4979                   The Darkness that Comes Before
# 5040                                   Use of Weapons
# 5057                              The Gods Themselves
#
#                                      tagged_description simple_categories  \
# 24    9780006513087 Emma Watson a research physician...               NaN
# 475   9780099410355 From the depths of catastrophe, ...               NaN
# 478   9780099422341 In aid of Amnesty International,...               NaN
# 491   9780099446729 Lestat Is Back, Saviour And Demo...               NaN
# 1090  9780261102422 Tolkien's Silmarillion is the co...               NaN
# 1435  9780340837955 Epic, entertaining, Stranger in ...               NaN
# 1439  9780345251220 The first novel in the series, "...               NaN
# 2845  9780575075597 At forty-three Jeff Winston is t...               NaN
# 2860  9780590254762 Four English school children ent...               NaN
# 3288  9780739423851 Howl's moving castle - Eldest of...               NaN
# 3289  9780739439708 Blending magic with quantum phys...               NaN
# 3563  9780760728505 Retells the adventures of a Fren...               NaN
# 4483  9781416502043 When the body of a half-drowned ...               NaN
# 4979  9781841494081 A score of centuries has passed ...               NaN
# 5040  9781857231359 The man known as Cheradenine Zak...               NaN
# 5057  9781857989342 In the year 2100, mankind on Ear...               NaN
#
#                                           description_y
# 24    Emma Watson a research physician has been trai...
# 475   From the depths of catastrophe, a glimmer of h...
# 478   In aid of Amnesty International, this is a bri...
# 491   Lestat Is Back, Saviour And Demon, Presiding O...
# 1090  Tolkien's Silmarillion is the core work of the...
# 1435  Epic, entertaining, Stranger in a Strange Land...
# 1439  The first novel in the series, "Return to the ...
# 2845  At forty-three Jeff Winston is tired of his lo...
# 2860  Four English school children enter the magic l...
# 3288  Howl's moving castle - Eldest of three sisters...
# 3289  Blending magic with quantum physics, Madeleine...
# 3563  Retells the adventures of a French professor a...
# 4483  When the body of a half-drowned elf is found f...
# 4979  A score of centuries has passed since the Firs...
# 5040  The man known as Cheradenine Zakalwe was one o...
# 5057  In the year 2100, mankind on Earth, settlers i...

# %%
books.to_csv("books_with_categories.csv",index=False)
